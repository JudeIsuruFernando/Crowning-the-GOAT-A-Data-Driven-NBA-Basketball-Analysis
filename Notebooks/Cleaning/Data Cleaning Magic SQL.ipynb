# %%
#!pip install mysql-connector-python

#!pip install ipython-sql pymysql

# %load_ext sql

# %sql mysql+pymysql://root:SQL%40123@localhost:3306/covid_portfolio_project

# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows
# FROM
#     covid_portfolio_project.covid_deaths
# WHERE
#     TRIM(weekly_hosp_admissions) = '';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/covid_portfolio_project
# 1 rows affected.
# [(80346,)]

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     covid_portfolio_project.covid_vaccinations
# LIMIT
#     5;
